# %%
import onnx
import mujoco
model = onnx.load("./model/Beyond_kick_level2.onnx")

# 检查模型输入输出
print("Inputs:")
for input in model.graph.input:
    shape = []
    for dim in input.type.tensor_type.shape.dim:
        if dim.dim_value > 0:
            shape.append(dim.dim_value)
        else:
            shape.append("None")  # 动态维度
    print(f"  {input.name}: {shape}")

print("Outputs:")
for output in model.graph.output:
    shape = []
    for dim in output.type.tensor_type.shape.dim:
        if dim.dim_value > 0:
            shape.append(dim.dim_value)
        else:
            shape.append("None")
    print(f"  {output.name}: {shape}")
# Out:
# Inputs:
#   obs: [1, 154]
#   time_step: [1, 1]
# Outputs:
#   actions: [1, 29]
#   joint_pos: [1, 29]
#   joint_vel: [1, 29]
#   body_pos_w: [1, 14, 3]
#   body_quat_w: [1, 14, 4]
#   body_lin_vel_w: [1, 14, 3]
#   body_ang_vel_w: [1, 14, 3]

# %%
import onnx
import mujoco
model = onnx.load("./model/policy_fightAndSports1_s1.onnx")

# 检查模型输入输出
print("Inputs:")
for input in model.graph.input:
    shape = []
    for dim in input.type.tensor_type.shape.dim:
        if dim.dim_value > 0:
            shape.append(dim.dim_value)
        else:
            shape.append("None")  # 动态维度
    print(f"  {input.name}: {shape}")

print("Outputs:")
for output in model.graph.output:
    shape = []
    for dim in output.type.tensor_type.shape.dim:
        if dim.dim_value > 0:
            shape.append(dim.dim_value)
        else:
            shape.append("None")
    print(f"  {output.name}: {shape}")
# Out:
# Inputs:
#   obs: [1, 154]
#   time_step: [1, 1]
# Outputs:
#   actions: [1, 29]
#   joint_pos: [1, 29]
#   joint_vel: [1, 29]
#   body_pos_w: [1, 14, 3]
#   body_quat_w: [1, 14, 4]
#   body_lin_vel_w: [1, 14, 3]
#   body_ang_vel_w: [1, 14, 3]
